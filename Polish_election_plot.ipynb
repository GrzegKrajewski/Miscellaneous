# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
exit_pool={'Prawo i Sprawiedliwość':36.8,'Koalicja Obywatelska':31.6,'Trzecia Droga':13,'Lewica':8.6,'Konfederacja':6.2}
d15={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[41.1,25.5,13.8,8,7.5],
    'Zliczono':[0.15,0.15,0.15,0.15,0.15]}
d20={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[40.5,26.1,13.9,8,7.5],
    'Zliczono':[0.20,0.20,0.20,0.20,0.20]}
d25={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[40.2,26.3,14,8.1,7.4],
    'Zliczono':[0.25,0.25,0.25,0.25,0.25]}
d30={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[39.9,26.5,14.1,8.1,7.4],
    'Zliczono':[0.30,0.30,0.30,0.30,0.30]}
d35={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[39.8,26.6,14.2,8.1,7.4],
    'Zliczono':[0.35,0.35,0.35,0.35,0.35]}
d40={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[39.3,27,14.3,8.1,7.4],
    'Zliczono':[0.40,0.40,0.40,0.40,0.40]}
d45={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[38.7,27.5,14.4,8.1,7.4],
    'Zliczono':[0.45,0.45,0.45,0.45,0.45]}
d55={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[37.97,28.19,14.38,8.23,7.30],
    'Zliczono':[0.555,0.555,0.555,0.555,0.555]}
d60={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[37.7,28.4,14.4,8.34,7.29],
    'Zliczono':[0.6,0.6,0.6,0.6,0.6]}
d65={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[37.52,28.59,14.43,8.31,7.28],
    'Zliczono':[0.65,0.65,0.65,0.65,0.65]}
d71={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[37.33,28.79,14.44,8.29,7.27],
    'Zliczono':[0.715,0.715,0.715,0.715,0.715]}
d75={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[37.03,29.1,14.48,8.31,7.24],
    'Zliczono':[0.751,0.751,0.751,0.751,0.751]}
d80={'Partia':['Prawo i Sprawiedliwość','Koalicja Obywatelska','Trzecia Droga','Lewica','Konfederacja'],
    'Wynik':[36.72,29.41,14.45,8.39,7.22],
    'Zliczono':[0.8,0.8,0.8,0.8,0.8]}
wyniki=pd.concat([pd.DataFrame(d15),pd.DataFrame(d20),pd.DataFrame(d25),pd.DataFrame(d30),pd.DataFrame(d35),pd.DataFrame(d40),pd.DataFrame(d45),
pd.DataFrame(d55),pd.DataFrame(d60),pd.DataFrame(d65),pd.DataFrame(d71),pd.DataFrame(d75),pd.DataFrame(d80)])

# %%
line_colors = ['blue', 'orange', 'green', 'red', 'purple']

plt.figure(figsize=(13, 8))
g=sns.lineplot(wyniki,x='Zliczono',y='Wynik',hue='Partia',palette=line_colors,linewidth=1.5)
g.set(ylim=(0,45),xlim=(0,1),xlabel='Zliczono komisji (%)',ylabel='Poparcie (%)',title='Poparcie dla poszczególnych Partii (linia przerywana - exit pool)')
xticks = [i / 20 for i in range(21)]  # Generate ticks every 0.05 from 0 to 1
plt.xticks(xticks, [f'{x:.2f}' for x in xticks])

for x in xticks:
    plt.axvline(x, color='gray', linestyle='--', linewidth=0.3)
    
for y in range (0,45,10):
    plt.axhline(y, color='gray', linestyle='--', linewidth=0.3)

for (partia, wynik), color in zip(exit_pool.items(),line_colors):
    plt.axhline(wynik,label=partia,color=color,linestyle='--',linewidth=1)

for i, j,color in zip(wyniki['Zliczono'], wyniki['Wynik'],line_colors*len(wyniki['Zliczono'])):
    plt.text(i, j, f'{j}', fontsize=11, va='bottom',color=color)
    plt.scatter(i, j, marker='o',color=color)
